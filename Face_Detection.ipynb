# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavshri1711/Book-Store/blob/main/Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %% [markdown]
# **Haar cascade**
#
# It is an object detection method

# %%
import cv2

# %% [markdown]
# https://github.com/opencv/opencv/tree/master/data/haarcascades

# %% [markdown]
# **load the Frontal face filter**

# %%
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
dir(face_cascade)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'convert',
#  'detectMultiScale',
#  'detectMultiScale2',
#  'detectMultiScale3',
#  'empty',
#  'getFeatureType',
#  'getOriginalWindowSize',
#  'isOldFormatCascade',
#  'load',
#  'read']

# %% [markdown]
# #### Image:

# %%
img=cv2.imread('/content/pic.jpg',
               cv2.COLOR_BGR2GRAY)
img
# Out:
# array([[[ 85,  92,  89],
#         [ 84,  91,  88],
#         [ 84,  91,  88],
#         ...,
#         [103, 115, 117],
#         [105, 117, 119],
#         [107, 119, 121]],
#
#        [[ 77,  84,  81],
#         [ 76,  83,  80],
#         [ 76,  83,  80],
#         ...,
#         [ 99, 111, 113],
#         [101, 113, 115],
#         [102, 114, 116]],
#
#        [[ 70,  77,  74],
#         [ 69,  76,  73],
#         [ 68,  75,  72],
#         ...,
#         [ 87,  99, 101],
#         [ 88, 100, 102],
#         [ 88, 100, 102]],
#
#        ...,
#
#        [[200, 216, 223],
#         [197, 213, 220],
#         [200, 211, 219],
#         ...,
#         [190, 201, 215],
#         [188, 201, 215],
#         [188, 202, 214]],
#
#        [[198, 214, 221],
#         [196, 212, 219],
#         [202, 213, 221],
#         ...,
#         [189, 200, 214],
#         [188, 201, 215],
#         [188, 202, 214]],
#
#        [[198, 214, 221],
#         [196, 212, 219],
#         [202, 213, 221],
# ...

# %%
#cv2.imshow("image",img)

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(img)  # open a new window to show the image
cv2.waitKey(0)          # if you want to close the image press 0
cv2.destroyAllWindows() # the window will be closed
# Out:
# <PIL.Image.Image image mode=RGB size=765x938>

# %%
from google.colab.patches import cv2_imshow # Import the library that replaces imshow
import cv2

# all together
# we are reading an image
# we are showing the imgage
# we are applying a wait key
# we are closing the image
img=cv2.imread('/content/pic.jpg',
               cv2.COLOR_BGR2RGB)

cv2_imshow(img)  # open a new window to show the image using cv2_imshow instead of cv2.imshow
cv2.waitKey(0)          # if you want to close the image press 0
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=765x938>

# %%
import matplotlib.pyplot as plt
frame=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(frame)

# %% [markdown]
# **cv2.rectangle**:
#
# - Image paths
#
# - start_window= (5,5)
#
# - end_window= (200,200)
#
# - BGR : (255,0,0)
#
# - thikness= 3

# %%
import cv2

img = cv2.imread('/content/pic.jpg', cv2.COLOR_BGR2GRAY)  # Updated path

if img is not None:  # Check if image loaded successfully
    print(img.shape)  # Check if image loaded successfully
else:
    print("Image not loaded. Check the file path.")
# Out:
# (938, 765, 3)

# %% [markdown]
# **Draw a Rectangualr box manually**

# %% [markdown]
# - Generally every bounding box will draw like below
#
# - It will give 4 values:(x,y,w,h)
#
# - Top left corner: (x,y)
#
# - Bottom right corner: (x+w,y+h)

# %%
from google.colab.patches import cv2_imshow # Import the cv2_imshow function
import cv2

img = cv2.imread('/content/pic.jpg', cv2.COLOR_BGR2GRAY)

start_window = (5, 5)  # Top left corner
end_window = (200, 200)  # Bottom right corner
color = (0, 0, 255)  # BGR 255=Red
thikness = 5
rec_image = cv2.rectangle(img, start_window, end_window, color, thikness)

cv2_imshow(rec_image)  # Use cv2_imshow instead of cv2.imshow

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=765x938>

# %% [markdown]
# **We use frontalface model to idenitify face**

# %%
img.shape
# Out:
# (938, 765, 3)

# %%
import cv2

 # Download the Haar Cascade file if it doesn't exist
# !wget -N https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml -P /content/

img = cv2.imread('/content/pic.jpg', cv2.COLOR_BGR2GRAY)
face_cascade = cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(img, 1.1, 4)

print(faces)

for (x, y, w, h) in faces:
     print(x, y)
     print(w, h)
     cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 3)  # B G R Red Is ON
# Out:
# --2025-01-09 05:33:19--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘/content/haarcascade_frontalface_default.xml’
#
# haarcascade_frontal 100%[===================>] 908.33K  --.-KB/s    in 0.02s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-01-09 05:33:19 (41.8 MB/s) - ‘/content/haarcascade_frontalface_default.xml’ saved [930127/930127]
#
# [[189 110 350 350]]
# 189 110
# 350 350

# %% [markdown]
# - x,y top left corner
#
# - x+w,y+h  bottom of right corner
#
# - Together it forms a rectangular box

# %%
from google.colab.patches import cv2_imshow # Importing the cv2_imshow function

cv2_imshow(img) # Displaying the image using cv2_imshow
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=765x938>

# %%
img=cv2.imread('C:\\Users\\omkar\\OneDrive\\Pictures\\Benjamin-Franklin.jpg',cv2.COLOR_BGR2GRAY)
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
faces=face_cascade.detectMultiScale(img,1.1,6)
print(faces)
for (x,y,w,h) in faces:
    print(x,y)
    print(w,h)
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),3)   # B G  R  Red Is ON

cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[152  38 184 184]]
# 152 38
# 184 184

# %%
#face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
#eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# %% [markdown]
# #### Video:

# %%
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
cap=cv2.VideoCapture(0)
while cap.isOpened():   # True or False
    has_frame,frame=cap.read() # cap.read will give two

    imag=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    faces=face_cascade.detectMultiScale(imag,1.1,4)
    for (x,y,w,h) in faces:
        cv2.rectangle(imag,(x,y),(x+h,y+w),(255,0,0),3)


    cv2.imshow('image',imag)
    if cv2.waitKey(1) & 0xFF== ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #### With eyeball:

# %%
import cv2
eye_cascade=cv2.CascadeClassifier('haarcascade_eye.xml')
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml') # full path

# %%
#img=cv2.imread('C:\\Users\\omkar\\OneDrive\\Documents\\Data science\\Naresh IT\\Data science\\Batch-1_May3\\DL\\Python codes\\my.jpg',
               #cv2.COLOR_BGR2GRAY)

# %%
import cv2
import os

try:
    # Try to access the camera using OpenCV
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        raise IOError("Cannot open webcam")

except Exception as e:
    # If accessing the camera fails, print an error message and install ngrok
    print(f"Error accessing camera: {e}")
    print("Installing ngrok...")
    # !pip install pyngrok --quiet
    from pyngrok import ngrok
    print("ngrok is installed successfully")

    # Authenticate with your ngrok authtoken (replace with your actual token)
    AUTH_TOKEN = "YOUR_ACTUAL_NGROK_AUTH_TOKEN"  # Replace with your actual ngrok authtoken
    ngrok.set_auth_token(AUTH_TOKEN)

    # Expose a public URL to access your webcam
    public_url = ngrok.connect(8080, "tcp").public_url
    print("Public URL:", public_url)

    # Update OpenCV to use the public URL (this might still fail depending on the setup)
    os.environ["OPENCV_VIDEOIO_PRIORITY_MSMF"] = "0"
    cap = cv2.VideoCapture(public_url)
    print("Video Capture using public URL")

# Rest of your code for face and eye detection remains the same
if cap.isOpened():
    while True:
        ret, frame = cap.read()
        if ret:
            # Display the frame
            from google.colab.patches import cv2_imshow  # Import here for Colab
            cv2_imshow(frame)

            # Break the loop if 'q' is pressed
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        else:
            break
    cap.release()
    cv2.destroyAllWindows()
else:
    print("Failed to start video capture.")
# Out:
# Error accessing camera: Cannot open webcam
# Installing ngrok...
# ngrok is installed successfully
# ERROR:pyngrok.process.ngrok:t=2025-01-09T05:45:07+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: The authtoken you specified does not look like a proper ngrok tunnel authtoken.\nYour authtoken: YOUR_ACTUAL_NGROK_AUTH_TOKEN\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n"
# ERROR:pyngrok.process.ngrok:t=2025-01-09T05:45:07+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: The authtoken you specified does not look like a proper ngrok tunnel authtoken.\nYour authtoken: YOUR_ACTUAL_NGROK_AUTH_TOKEN\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n"
# ...

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------

# %%
a=10
b=20
a+b
# Out:
# 30

# %%
# down laod the
#  smile
#  upper body
#  licnce plate detect the
